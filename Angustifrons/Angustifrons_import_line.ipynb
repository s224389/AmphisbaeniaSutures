# %%
from myHelperFunctions import*
# Out:
# starting functions
# Functions loaded

# %% [markdown]
# # Code

# %%
# %matplotlib inline

# %%
vertex_data = load_data_npy('Angustifrons_skeleton.npy')
my_scatter(vertex_data,camera_view=(30,90))

# %%
sorted_points = my_sort_points(vertex_data, 6)
my_scatter(sorted_points,camera_view=(30,90))

# %%
# %matplotlib inline

# %%
interp_points = interpolate_3d_points(sorted_points, 5,15,camera_view=(30,90))
# Out:
# Number of interpolated points:  226

# %%
smoothed_points = smoothing_signal(interp_points, 10,1,camera_view=(30,90))
# Out:
# Number of smoothed points:  226

# %%
centers, radii = calculate_radii(smoothed_points)
# Out:
# Radii shape: (226,)
# equidistant_points shape: (226, 3)
# min of radii: 1.882716763152584
# max of radii: 930059459946067.0

# %%
# %matplotlib qt5

# %%
temp = plot_turning_points(smoothed_points, radii, 33, 5, camera_view=(30,90))
temp
# Out:
# Number of turning points: 9
# [11, 60, 79, 96, 112, 128, 143, 166, 216]

# %%
dist, tot_length, tortousity, volume = curve_characteristics(smoothed_points)
# Out:
#  The distance between the start and end point is: 158.56354932150893 Voxels
#  The total length of the line is: 597.3946509606242 Voxels
#  The tortuosity of the line is: 3.7675408599067506
#  The volume of the bounding box is:  3370866.0159863895 Voxels

# %%
dist, tot_length, tortousity, volume
# Out:
# (158.56354932150893, 597.3946509606242, 3.7675408599067506, 3370866.0159863895)

# %% [markdown]
# ### Saving smoothed points

# %%
#np.save('Angustifrons_smoothed.npy', smoothed_points)
