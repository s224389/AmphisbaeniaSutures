# %%
from myHelperFunctions import*
# Out:
# starting functions
# Functions loaded

# %% [markdown]
# # Code

# %%
# %matplotlib inline

# %%
vertex_data = load_data_npy("Bipes_tridactylus_skeleton.npy")
my_scatter(vertex_data,camera_view=(30,-60))

# %%
sorted_points = my_sort_points_max_x(vertex_data, 15)
my_scatter(sorted_points,camera_view=(30,-60))

# %%
# %matplotlib inline

# %%
interp_points = interpolate_3d_points(sorted_points, 5,20,camera_view=(30,-60))
# Out:
# Number of interpolated points:  241

# %%
smoothed_points = smoothing_signal(interp_points, 7, 1, camera_view=(30,-60))
# Out:
# Number of smoothed points:  241

# %%
centers, radii = calculate_radii(smoothed_points)
# Out:
# Radii shape: (241,)
# equidistant_points shape: (241, 3)
# min of radii: 2.7524491992654703
# max of radii: 450007181031197.1

# %%
# %matplotlib qt5

# %%
turning_points = plot_turning_points(smoothed_points, radii, 25, 13, camera_view=(30,-60))
# Out:
# Number of turning points: 12

# %%
dist, tot_length, tortousity, volume = curve_characteristics(smoothed_points)
# Out:
#  The distance between the start and end point is: 230.83275055157222 Voxels
#  The total length of the line is: 770.9809656921935 Voxels
#  The tortuosity of the line is: 3.3399981755186094
#  The volume of the bounding box is:  2141760.3131905585 Voxels

# %%
dist, tot_length, tortousity, volume
# Out:
# (230.83275055157222, 770.9809656921935, 3.3399981755186094, 2141760.3131905585)
